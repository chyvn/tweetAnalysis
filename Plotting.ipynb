# %%
import matplotlib.pyplot as plt

y = [20, 40, 60, 80, 100]
x1 = [90.1, 91.2, 92.4, 93.0, 95]
x2 = [91.8, 92.4, 94.1, 94.7, 95.8]
x3 = [93.6, 94.7, 95.1, 95.7, 96.2]
x4 = [94.1, 95.2, 95.6, 96.2, 97.3]
x5 = [95.0, 96.4, 96.8, 97.3, 98.0]
x6 = [95.1, 96.3, 96.9, 97.5, 98.4]

plt.figure(figsize=(9,6.5))
plt.title('Comparision of PDR ')

plt.plot(y, x1, label = 'AMODV-A')
plt.plot(y, x2, label = 'AMODV')
plt.plot(y, x3, label = 'AMODV-AP')
plt.plot(y, x4, label = 'AMODV-AP-overhead change')
plt.plot(y, x6, label = 'Proposed Scheme')
plt.xlabel('Iterations')
plt.ylabel('Packet Delivery Ratio')

legend = plt.legend()
plt.show()

# %%
# !pip3 install matplotlib
# Out:
# ...
#     100% |████████████████████████████████| 12.6MB 71kB/s eta 0:00:011
# ...
#   Using cached python_dateutil-2.7.2-py2.py3-none-any.whl
# ...
#   Using cached pyparsing-2.2.0-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 952kB 488kB/s ta 0:00:01
# ...
#   Using cached six-1.11.0-py2.py3-none-any.whl
# ...
#   Using cached pytz-2018.4-py2.py3-none-any.whl
# ...
#   Using cached numpy-1.14.2-cp35-cp35m-manylinux1_x86_64.whl
# ...
#   Using cached setuptools-39.0.1-py2.py3-none-any.whl
# ...
# You are using pip version 8.1.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
